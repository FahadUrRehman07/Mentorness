# %% [markdown]
# <h1 style="background: linear-gradient(to right, #F4A261, #E76F51);
#            text-align: center;
#            color: #254336;
#            padding: 15px;
#            margin: 5px;
#            border-radius: 2px;
#            box-shadow: 0 8px 16px rgba(0, 0, 0, 0.3);">🕊💡 Electricity Consumption Prediction💡🕊️</h1>

# %% [markdown]
# <table style="width: 80%; border-collapse: collapse; text-align: left; border: 1px solid #ddd; box-shadow: 0 8px 16px rgba(224, 167, 94, 0.3);">
#   <tr>
#     <th style="background: linear-gradient(to right, #E0A75E, #F9D689);
#                color: #2c3e50;
#                padding: 10px;
#                text-align: center;
#                border-bottom: 2px solid #ddd;
#                border-left: 2px solid #ddd;
#                border-top: 2px solid #ddd;">Name</th>
#     <th style="padding: 10px;
#                background: linear-gradient(to right, #E0A75E, #F9D689);
#                color: #2c3e50;
#                text-align: left;
#                border-bottom: 2px solid #ddd;
#                border-top: 2px solid #ddd;">Email</th>
#     <th style="padding: 10px;
#                background: linear-gradient(to right, #E0A75E, #F9D689);
#                color: #2c3e50;
#                padding-left: 20px;
#                text-align: left;
#                border-bottom: 2px solid #ddd;
#                border-top: 2px solid #ddd;">LinkedIn</th>
#     <th style="padding: 10px;
#                background: linear-gradient(to right, #E0A75E, #F9D689);
#                color: #2c3e50;
#                padding-left: 15px;
#                text-align: left;
#                border-bottom: 2px solid #ddd;
#                border-top: 2px solid #ddd;">GitHub</th>
#     <th style="padding: 10px;
#                background: linear-gradient(to right, #E0A75E, #F9D689);
#                color: #2c3e50;
#                text-align: left;
#                border-bottom: 2px solid #ddd;
#                border-right: 2px solid #ddd;
#                border-top: 2px solid #ddd;">Kaggle</th>
#   </tr>
#   <tr>
#     <td style="padding-left: 0px; border-bottom: 2px solid #ddd; text-align: center;">Fahad Rehman</td>
#     <td style="padding-left: 2px; border-bottom: 2px solid #ddd; text-align: right;">fahadrehmann07@gmail.com</td>
#     <td style="padding-left: 20px; border-bottom: 2px solid #ddd; text-align: left;">
#       <a href="https://www.linkedin.com/in/fahad-rehman-datascience/" style="text-decoration: none; color: #2c3e50;">
#         LinkedIn
#       </a>
#     </td>
#     <td style="padding-left: 15px; border-bottom: 2px solid #ddd; text-align: left;">
#       <a href="https://github.com/FahadUrRehman07" style="text-decoration: none; color: #2c3e50;">
#         GitHub
#       </a>
#     </td>
#     <td style="padding: 10px; border-bottom: 2px solid #ddd; text-align: left;">
#       <a href="https://www.kaggle.com/fahadrehman07" style="text-decoration: none; color: #2c3e50;">
#         Kaggle
#       </a>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ## Problem Statement:
# This internship project is focused on leveraging Python for time series prediction of household
# electricity consumption. The dataset includes essential features such as date, time, global active
# power, global reactive power, voltage, global intensity, and sub-metering values. The objective is to
# build robust time series forecasting models that can accurately predict future electricity
# consumption trends based on historical data. The insights derived from this analysis can empower
# households to optimize energy usage, plan efficiently, and contribute to sustainable energy
# practices.
# ## Dataset Description:
# 1. Date: Date of the electricity consumption recording.
# 2. Time: Time of the electricity consumption recording.
# 3. Global_active_power: Total active power consumed by the household.
# 4. Global_reactive_power: Total reactive power consumed by the household.
# 5. Voltage: Voltage level during the electricity consumption period.
# 6. Global_intensity: Total current intensity consumed by the household.
# 7. Sub_metering_1: Electricity consumption in sub-metering 1 (e.g., kitchen).
# 8. Sub_metering_2: Electricity consumption in sub-metering 2 (e.g., laundry).
# 9. Sub_metering_3: Electricity consumption in sub-metering 3 (e.g., water heater).
# ## Project Objectives:
# #### 1. Data Preprocessing:
#  - Clean and preprocess the dataset, handling any missing values or outliers.
#  - Combine the date and time columns into a datetime format for effective time series analysis.
# #### 2. Exploratory Data Analysis (EDA):
#  - Conduct EDA to uncover patterns, trends, and seasonality in electricity consumption.
#  - Visualize the relationships between different features to gain insights.
# #### 3. Time Series Forecasting Models:
#  - Implement time series forecasting models such as ARIMA, SARIMA, or LSTM.
#  - Evaluate the performance of the models using appropriate metrics.
# #### 4. Feature Engineering:
#  - Investigate the impact of various features on electricity consumption.
#  - Explore the creation of new features that might enhance prediction accuracy.
# #### 5. Model Evaluation and Tuning:
#  - Fine-tune model hyperparameters for optimal performance.
#  - Validate and optimize the model using a separate test dataset.
# #### 6. Future Consumption Prediction:
#  - Generate forecasts for future electricity consumption based on the trained models.
#  - Visualize and interpret the predictions to identify potential consumption patterns.
# ## Deliverables:
# - Python scripts for data preprocessing, EDA, and time series prediction models.
# - Visualizations illustrating consumption patterns, model evaluation metrics, and predicted future trends.
# - A comprehensive report summarizing the findings, challenges encountered, and recommendations for optimizing household electricity consumption.
#
# This project equips interns with hands-on experience in time series analysis, forecasting, and feature
# engineering, contributing to the broader goal of promoting energy-efficient practices in households

# %% [markdown]
# # Importing Libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import ListedColormap


from statsmodels.tsa.seasonal import seasonal_decompose

from pandas.plotting import lag_plot, autocorrelation_plot

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('household_power_consumption.txt', delimiter=';')

# %%
df.head()
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %% [markdown]
# # Data Preprocessing:
#
# - Clean and preprocess the dataset, handling any missing values or outliers.
#  - Combine the date and time columns into a datetime format for effective time series analysis.

# %% [markdown]
# ### Converting Data and time to dataTime formate:

# %%
df['Datetime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'])
df.set_index('Datetime', inplace=True)
df.drop(columns=['Date', 'Time'], inplace=True)

# %%
df.head()
# Out:
#                     Global_active_power Global_reactive_power  Voltage  \
# Datetime
# 2006-12-16 17:24:00               4.216                 0.418  234.840
# 2006-12-16 17:25:00               5.360                 0.436  233.630
# 2006-12-16 17:26:00               5.374                 0.498  233.290
# 2006-12-16 17:27:00               5.388                 0.502  233.740
# 2006-12-16 17:28:00               3.666                 0.528  235.680
#
#                     Global_intensity Sub_metering_1 Sub_metering_2  \
# Datetime
# 2006-12-16 17:24:00           18.400          0.000          1.000
# 2006-12-16 17:25:00           23.000          0.000          1.000
# 2006-12-16 17:26:00           23.000          0.000          2.000
# 2006-12-16 17:27:00           23.000          0.000          1.000
# 2006-12-16 17:28:00           15.800          0.000          1.000
#
#                      Sub_metering_3
# Datetime
# 2006-12-16 17:24:00            17.0
# ...

# %% [markdown]
# ## Renaming columns:
#
# - Sub_metering_1 to Kitchen_EC
# - Sub_metering_2 to laundry_EC
# - Sub_metering_3 to Water_Heater_EC

# %%
df.rename(columns={'Sub_metering_1': 'Kitchen_EC', 'Sub_metering_2': 'laundry_EC' , 'Sub_metering_3': 'Water_Heater_EC'}, inplace=True)
df.head()
# Out:
#                     Global_active_power Global_reactive_power  Voltage  \
# Datetime
# 2006-12-16 17:24:00               4.216                 0.418  234.840
# 2006-12-16 17:25:00               5.360                 0.436  233.630
# 2006-12-16 17:26:00               5.374                 0.498  233.290
# 2006-12-16 17:27:00               5.388                 0.502  233.740
# 2006-12-16 17:28:00               3.666                 0.528  235.680
#
#                     Global_intensity Kitchen_EC laundry_EC  Water_Heater_EC
# Datetime
# 2006-12-16 17:24:00           18.400      0.000      1.000             17.0
# 2006-12-16 17:25:00           23.000      0.000      1.000             16.0
# 2006-12-16 17:26:00           23.000      0.000      2.000             17.0
# 2006-12-16 17:27:00           23.000      0.000      1.000             17.0
# 2006-12-16 17:28:00           15.800      0.000      1.000             17.0

# %% [markdown]
# ## Handling missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2075259 entries, 2006-12-16 17:24:00 to 2010-11-26 21:02:00
# Data columns (total 7 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Global_active_power    object
#  1   Global_reactive_power  object
#  2   Voltage                object
#  3   Global_intensity       object
#  4   Kitchen_EC             object
#  5   laundry_EC             object
#  6   Water_Heater_EC        float64
# dtypes: float64(1), object(6)
# memory usage: 126.7+ MB

# %%
df.isna().sum()
# Out:
# Global_active_power          0
# Global_reactive_power        0
# Voltage                      0
# Global_intensity             0
# Kitchen_EC                   0
# laundry_EC                   0
# Water_Heater_EC          25979
# dtype: int64

# %% [markdown]
# ### Removing missing values

# %%
df.dropna(inplace=True)
print(df.isna().sum())
df.info()
# Out:
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Kitchen_EC               0
# laundry_EC               0
# Water_Heater_EC          0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2049280 entries, 2006-12-16 17:24:00 to 2010-11-26 21:02:00
# Data columns (total 7 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Global_active_power    object
#  1   Global_reactive_power  object
#  2   Voltage                object
#  3   Global_intensity       object
#  4   Kitchen_EC             object
#  5   laundry_EC             object
#  6   Water_Heater_EC        float64
# dtypes: float64(1), object(6)
# memory usage: 125.1+ MB

# %% [markdown]
# ## Handling Outliers

# %% [markdown]
# - Select Only Numerical Columns
# - Calculate Q1 (25th percentile) and Q3 (75th percentile).
# - Define a mask to filter out the outliers.
# - Keep only the rows without Outliers.

# %%
# numerical columns
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Calculate Q1  and Q3
Q1 = df[numeric_cols].quantile(0.25)
Q3 = df[numeric_cols].quantile(0.75)
IQR = Q3 - Q1

# Mask to filter out outliers
mask = (df[numeric_cols] >= (Q1 - 1.5 * IQR)) & (df[numeric_cols] <= (Q3 + 1.5 * IQR))

# Rows without outliers
df_cleaned = df[mask.all(axis=1)]

# %%
df_cleaned.head()
# Out:
#                     Global_active_power Global_reactive_power  Voltage  \
# Datetime
# 2006-12-16 17:24:00               4.216                 0.418  234.840
# 2006-12-16 17:25:00               5.360                 0.436  233.630
# 2006-12-16 17:26:00               5.374                 0.498  233.290
# 2006-12-16 17:27:00               5.388                 0.502  233.740
# 2006-12-16 17:28:00               3.666                 0.528  235.680
#
#                     Global_intensity Kitchen_EC laundry_EC  Water_Heater_EC
# Datetime
# 2006-12-16 17:24:00           18.400      0.000      1.000             17.0
# 2006-12-16 17:25:00           23.000      0.000      1.000             16.0
# 2006-12-16 17:26:00           23.000      0.000      2.000             17.0
# 2006-12-16 17:27:00           23.000      0.000      1.000             17.0
# 2006-12-16 17:28:00           15.800      0.000      1.000             17.0

# %% [markdown]
# # Exploratory Data Analysis(EDA):
#
# - Conduct EDA to uncover patterns, trends, and seasonality in electricity consumption.
# - Visualize the relationships between different features to gain insights.

# %% [markdown]
# ### Step 1: Basic Information and Summary Statistics
# - Get a basic understanding of the dataset.

# %%
# Display basic information
print(df.info())

# Display summary statistics
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2049280 entries, 2006-12-16 17:24:00 to 2010-11-26 21:02:00
# Data columns (total 7 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Global_active_power    object
#  1   Global_reactive_power  object
#  2   Voltage                object
#  3   Global_intensity       object
#  4   Kitchen_EC             object
#  5   laundry_EC             object
#  6   Water_Heater_EC        float64
# dtypes: float64(1), object(6)
# memory usage: 125.1+ MB
# None
#        Water_Heater_EC
# count     2.049280e+06
# mean      6.458447e+00
# std       8.437154e+00
# min       0.000000e+00
# 25%       0.000000e+00
# 50%       1.000000e+00
# 75%       1.700000e+01
# max       3.100000e+01

# %% [markdown]
# ### Step 2: Visualizing Time Series Data
# - Plotting the time series data to observe trends and seasonality.

# %%
df[['Global_active_power','Kitchen_EC']] = df[['Global_active_power','Kitchen_EC']].astype(float)

# Then convert 'Global_active_power' to integer
df['Global_active_power'] = df['Global_active_power'].astype(int)

# Plot Global Active Power over time
plt.figure(figsize=(15, 6))
plt.plot(df['Global_active_power'], label='Global Active Power')
plt.title('Global Active Power Over Time')
plt.xlabel('Datetime')
plt.ylabel('Global Active Power (kilowatts)')
plt.legend()
plt.show()

# %% [markdown]
# ### Step 3: Visualizing Relationships Between Features
# - Use pair plots and correlation matrices to understand relationships between different features.

# %%
# Pairplot to visualize relationships
sns.pairplot(df)
plt.show()

# Correlation matrix
corr_matrix = df.corr()
plt.figure(figsize=(6, 4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Step 5: Analyzing Seasonality and Trends
# - Decompose the time series to observe seasonality, trend, and residual components.

# %%
# Decompose the time series
decomposition = seasonal_decompose(df['Global_active_power'], model='additive', period=365)

# Plot the decomposed components
plt.figure(figsize=(15, 10))
plt.subplot(411)
plt.plot(decomposition.observed, label='Observed')
plt.legend(loc='upper left')
plt.subplot(412)
plt.plot(decomposition.trend, label='Trend')
plt.legend(loc='upper left')
plt.subplot(413)
plt.plot(decomposition.seasonal, label='Seasonality')
plt.legend(loc='upper left')
plt.subplot(414)
plt.plot(decomposition.resid, label='Residuals')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 6: Analyzing Distribution and Density
# - Examine the distribution and density of the numerical features.

# %%
# Distribution of Global Active Power
plt.figure(figsize=(10, 6))
sns.histplot(df['Global_active_power'], bins=50, kde=True)
plt.title('Distribution of Global Active Power')
plt.xlabel('Global Active Power (kilowatts)')
plt.ylabel('Frequency')
plt.show()

# Density plot
plt.figure(figsize=(10, 6))
sns.kdeplot(df['Global_active_power'], shade=True)
plt.title('Density Plot of Global Active Power')
plt.xlabel('Global Active Power (kilowatts)')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ### Step 6: Box Plots and Outliers Analysis
# - Use box plots to visualize the distribution and identify potential outliers.

# %%
# Box plot for Global Active Power
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Global_active_power'])
plt.title('Box Plot of Global Active Power')
plt.xlabel('Global Active Power (kilowatts)')
plt.show()

# %% [markdown]
# ### Step 7: Time-Based Grouping and Aggregation
# - Analyze the data by aggregating it over different time intervals (e.g., hourly, daily, monthly).

# %%
# Resample to daily frequency and calculate mean
daily_data = df['Global_active_power'].resample('D').mean()

# Plot daily data
plt.figure(figsize=(15, 6))
plt.plot(daily_data, label='Daily Mean Global Active Power')
plt.title('Daily Mean Global Active Power Over Time')
plt.xlabel('Datetime')
plt.ylabel('Global Active Power (kilowatts)')
plt.legend()
plt.show()

# Monthly aggregation
monthly_data = df['Global_active_power'].resample('M').mean()

# Plot monthly data
plt.figure(figsize=(15, 6))
plt.plot(monthly_data, label='Monthly Mean Global Active Power')
plt.title('Monthly Mean Global Active Power Over Time')
plt.xlabel('Datetime')
plt.ylabel('Global Active Power (kilowatts)')
plt.legend()
plt.show()

# %% [markdown]
# ### Step 8: Lag and Autocorrelation Analysis
# - Analyze the autocorrelation to understand the relationship between current and past values.

# %%
# Lag plot
plt.figure(figsize=(10, 6))
lag_plot(df['Global_active_power'])
plt.title('Lag Plot of Global Active Power')
plt.show()

# Autocorrelation plot
plt.figure(figsize=(10, 6))
autocorrelation_plot(df['Global_active_power'])
plt.title('Autocorrelation Plot of Global Active Power')
plt.show()

# %% [markdown]
# # 3. Time Series Forecasting Models:
# ## ARIMA Model:

# %%
from statsmodels.tsa.arima_model import ARIMA

# Fit model
model = ARIMA(df['Global_active_power'], order=(5,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())

# %% [markdown]
# ## LSTM Model:

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df['Global_active_power'].values.reshape(-1, 1))

# Prepare data for LSTM
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 10
X, Y = create_dataset(scaled_data, look_back)
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(look_back, 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X, Y, batch_size=1, epochs=1)

# %% [markdown]
# # 4. Feature Engineering:
#
# ## Creating New Features:

# %%
df['Hour'] = df.index.hour
df['Day'] = df.index.day
df['Month'] = df.index.month
df['Year'] = df.index.year

# %% [markdown]
# # 5. Model Evaluation and Tuning:
# ## Model Evaluation Metrics:

# %%
from sklearn.metrics import mean_squared_error

# Assuming predictions and actual values
mse = mean_squared_error(actual, predictions)
print(f'Mean Squared Error: {mse}')

# %% [markdown]
# ## Hyperparameter Tuning:

# %%
# Grid search for ARIMA
import itertools

p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))

best_score, best_params = float("inf"), None
for param in pdq:
    try:
        model = ARIMA(df['Global_active_power'], order=param)
        results = model.fit()
        if results.aic < best_score:
            best_score, best_params = results.aic, param
    except:
        continue
print(f'Best ARIMA parameters: {best_params} with AIC: {best_score}')

# %% [markdown]
# # 6. Future Consumption Prediction:
# ## Generate Forecasts:

# %%
forecast = model_fit.forecast(steps=10)
print(forecast)

# %% [markdown]
# ## Visualize Predictions:

# %%
plt.figure(figsize=(15, 6))
plt.plot(df['Global_active_power'], label='Actual')
plt.plot(pd.date_range(start=df.index[-1], periods=10, freq='D'), forecast, label='Forecast')
plt.legend()
plt.title('Electricity Consumption Forecast')
plt.show()
